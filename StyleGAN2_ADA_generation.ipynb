# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install opensimplex

# %%
# !git clone https://github.com/dvschultz/stylegan2-ada.git
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 297 (delta 42), reused 49 (delta 24), pack-reused 217
# Receiving objects: 100% (297/297), 56.16 MiB | 33.30 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import shutil

network = '/content/gdrive/My Drive/network-snapshot-001024.pkl'
out_dir = 'out'
seeds = ','.join([str(i) for i in range(101, 200)])

# %%
# Generate images and build a zip archive
# !python stylegan2-ada/generate.py generate-images --outdir={out_dir} --seeds={seeds} --network="/content/gdrive/My Drive/network-snapshot-001024.pkl"
shutil.make_archive('pictures', 'zip', 'out')
# Out:
# Loading networks from "/content/gdrive/My Drive/network-snapshot-001024.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 101 (0/99) ...
# Generating image for seed 102 (1/99) ...
# Generating image for seed 103 (2/99) ...
# Generating image for seed 104 (3/99) ...
# Generating image for seed 105 (4/99) ...
# Generating image for seed 106 (5/99) ...
# Generating image for seed 107 (6/99) ...
# Generating image for seed 108 (7/99) ...
# Generating image for seed 109 (8/99) ...
# Generating image for seed 110 (9/99) ...
# Generating image for seed 111 (10/99) ...
# Generating image for seed 112 (11/99) ...
# Generating image for seed 113 (12/99) ...
# Generating image for seed 114 (13/99) ...
# Generating image for seed 115 (14/99) ...
# Generating image for seed 116 (15/99) ...
# Generating image for seed 117 (16/99) ...
# Generating image for seed 118 (17/99) ...
# ...

# %%
# Generate interpolation
# !python stylegan2-ada/generate.py generate-latent-walk --frames=500 --outdir=out_interpolation --seeds=15,14,172,87,34,139,79,82,69,188,88,170,152,177 --network="/content/gdrive/My Drive/network-snapshot-001024.pkl"
# Out:
# Loading networks from "/content/gdrive/My Drive/network-snapshot-001024.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for step 0/507 ...
# Generating image for step 1/507 ...
# Generating image for step 2/507 ...
# Generating image for step 3/507 ...
# Generating image for step 4/507 ...
# Generating image for step 5/507 ...
# Generating image for step 6/507 ...
# Generating image for step 7/507 ...
# Generating image for step 8/507 ...
# Generating image for step 9/507 ...
# Generating image for step 10/507 ...
# Generating image for step 11/507 ...
# Generating image for step 12/507 ...
# Generating image for step 13/507 ...
# Generating image for step 14/507 ...
# Generating image for step 15/507 ...
# Generating image for step 16/507 ...
# Generating image for step 17/507 ...
# Generating image for step 18/507 ...
# Generating image for step 19/507 ...
# ...

# %%
shutil.make_archive('out_interpolation', 'zip', 'out_interpolation')
# Out:
# '/content/out_interpolation.zip'

# %%
shutil.copy('/content/out_interpolation.zip', '/content/gdrive/My Drive/images/out_interpolation_3.zip')
# Out:
# '/content/gdrive/My Drive/images/out_interpolation_3.zip'

# %%
shutil.copy('/content/pictures.zip', '/content/gdrive/My Drive/images/pictures.zip')
# Out:
# '/content/gdrive/My Drive/images/pictures.zip'
